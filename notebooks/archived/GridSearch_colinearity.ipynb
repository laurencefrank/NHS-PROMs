# %% [markdown]
# # Refactored notebook for modelling

# %% [markdown]
# ## imports

# %%
import sys

sys.path.append("..")

import numpy as np
import pandas as pd
import warnings
import re
import plotly.express as px
import plotly.graph_objects as go

from NHS_PROMs.load_data import load_proms, structure_name
from NHS_PROMs.preprocess import filter_in_range, filter_in_labels, method_delta
from NHS_PROMs.utils import (
    downcast,
    map_labels,
    fillna_categories,
    pd_fit_resample,
    infer_categories_fit,
    KindSelector,
    get_feature_names,
    remove_categories,
)
from NHS_PROMs.data_dictionary import meta_dict, methods

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import make_column_selector
from sklearn.base import BaseEstimator, TransformerMixin

# from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import (
    ColumnTransformer, 
    make_column_transformer,
    make_column_selector,
)
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingRegressor,
    BaggingClassifier,
)
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.inspection import permutation_importance
from sklearn import set_config

set_config(display="diagram")

from imblearn.ensemble import BalancedBaggingClassifier, BalancedRandomForestClassifier, EasyEnsembleClassifier
from imblearn.over_sampling import SMOTENC
from imblearn.pipeline import Pipeline, make_pipeline
from imblearn.under_sampling import RandomUnderSampler 

# use adjusted fillna which can cope with non-existing categories for CategoricalDtype
pd.core.frame.DataFrame.fillna = fillna_categories
# added a remove categories
pd.core.frame.Series.remove_categories = remove_categories
# enable autodetect of categories from CategoricalDtype by using "infer" for SMOTENC
SMOTENC.fit_resample = pd_fit_resample(SMOTENC.fit_resample)
# enable inference of categories for encoders from CategoricalDtype
OneHotEncoder.fit = infer_categories_fit(OneHotEncoder.fit)
OrdinalEncoder.fit = infer_categories_fit(OrdinalEncoder.fit)

# %% [markdown]
# ## load data
# General approach is not DRY for the sake of availability of having knee and hip df's always at hand, but also keep it readable (script-wise).

# %%
# load data + rename columns with structired name
# df_knee_raw = load_proms(part="knee").apply(downcast).rename(structure_name, axis=1)
df_hip_raw = load_proms(part="hip").apply(downcast).rename(structure_name, axis=1)

# get meta data for each
full_meta = {t + k: v for k, v in meta_dict.items() for t in ["t0_", "t1_"]}
hip_meta = {k: v for k, v in full_meta.items() if k in df_hip_raw.columns}

df_hip_raw.sample(3)
# Out:
#       t0_provider_code     t0_procedure  t0_revision_flag  t0_year  \
# 3319             ADP02  Hip Replacement                 0  2018/19
# 10282            NV302  Hip Replacement                 0  2018/19
# 16077              RR8  Hip Replacement                 0  2019/20
#
#       t0_age_band  t0_gender  t0_assisted  t0_assisted_by  t0_symptom_period  \
# 3319     70 to 79        2.0            2               0                  2
# 10282    60 to 69        1.0            2               0                  2
# 16077    80 to 89        1.0            2               0                  2
#
#        t0_previous_surgery  ...  t1_ohs_transport  t1_ohs_dressing  \
# 3319                     2  ...                 3                2
# 10282                    2  ...                 4                0
# 16077                    2  ...                 4                3
#
#        t1_ohs_shopping  t1_ohs_walking  t1_ohs_limping  t1_ohs_stairs  \
# 3319                 4               3               3              2
# 10282                4               4               4              4
# 16077                4               4               3              4
#
#        t1_ohs_standing  t1_ohs_work  t1_ohs_score  t1_ohs_predicted
# 3319                 3            3          35.0         37.559242
# 10282                4            4          44.0         38.390038
# 16077                4            4          46.0         37.626877
#
# [3 rows x 81 columns]

# %% [markdown]
# ## basic cleaning

# %%
# %%time

endings = (
    "code", # is a coded score and not of interest for the case
    "procedure", # is the same for the hip or knee set
    "revision_flag", # revisions are out of scope, filtered away, so same for all rows after that
    "assisted_by", # is the same for all records
    "profile", # is a coded score and not of interest for the case
    "predicted", # are predictions of other models that are not supposed to be used
)
cols2drop = [c for c in df_hip_raw.columns if c.endswith(endings)]

df_hip_clean = (
    df_hip_raw.apply(lambda s: filter_in_range(s, **hip_meta[s.name])) # filter in range numeric features
    .apply(lambda s: filter_in_labels(s, **hip_meta[s.name])) # filter in labels categorical features + ordinal if ordered
    .apply(lambda s: map_labels(s, **hip_meta[s.name])) # map the labels as values for readability
    .query("t0_revision_flag == 'no revision'") # drop revision cases
    .drop(columns=cols2drop) # drop not needed columns
    .reset_index(drop=True) # make index unique (prevent blow ups when joining)
)

# remove NaNs/missing/unknown from numerical and ordinal features
df_hip_clean = (
    df_hip_clean.apply(pd.Series.remove_categories, args=(["missing", "not known"],))
    .dropna(subset= KindSelector(kind="numerical")(df_hip_clean) + KindSelector(kind="ordinal")(df_hip_clean))
)

df_hip_clean.sample(3)
# Out:
# CPU times: user 807 ms, sys: 101 ms, total: 909 ms
# Wall time: 922 ms
#                         t0_year t0_age_band t0_gender t0_assisted  \
# 114101  April 2018 - April 2019    80 to 89    female         yes
# 33584   April 2016 - April 2017    70 to 79    female          no
# 9396    April 2016 - April 2017    50 to 59      male          no
#
#        t0_symptom_period t0_previous_surgery  \
# 114101      1 to 5 years                  no
# 33584       1 to 5 years                  no
# 9396        1 to 5 years                  no
#
#                           t0_living_arrangements t0_disability  \
# 114101  with partner / spouse / family / friends           yes
# 33584                                      other           yes
# 9396    with partner / spouse / family / friends            no
#
#        t0_heart_disease t0_high_bp  ... t1_ohs_washing  \
# 114101              NaN        yes  ...   rarely/never
# 33584               NaN        yes  ...   rarely/never
# 9396                NaN        yes  ...   rarely/never
#
#                   t1_ohs_transport             t1_ohs_dressing  \
# 114101    often, not just at first  sometimes or just at first
# 33584   sometimes or just at first    often, not just at first
# 9396                  rarely/never                rarely/never
#
#         t1_ohs_shopping            t1_ohs_walking              t1_ohs_limping  \
# 114101  all of the time  often, not just at first             all of the time
# 33584      rarely/never              rarely/never  sometimes or just at first
# 9396       rarely/never              rarely/never                rarely/never
#
#                      t1_ohs_stairs           t1_ohs_standing  \
# 114101            most of the time  often, not just at first
# 33584   sometimes or just at first              rarely/never
# 9396                  rarely/never              rarely/never
#
#                        t1_ohs_work t1_ohs_score
# 114101            most of the time         23.0
# 33584   sometimes or just at first         42.0
# 9396                  rarely/never         48.0
#
# [3 rows x 71 columns]

# %% [markdown]
# ### Explanation why we can drop years

# %%
# def plot_year_histograms(t=0, method="eq5d"):
    
#     facet_cols = ["_".join([f"t{t}", method, dim]) for dim in methods[method]["dims"]["names"]]

#     df_plot = (
#         df_hip_clean[["t0_year"] + facet_cols]
#         .set_index("t0_year")
#         .stack()
#         .reset_index()
#         .set_axis(["year", "dimension", "value"], axis=1)
#     )

#     fig = px.histogram(
#         df_plot,
#         title=f"Distributions of values over the years for method {method} at t{t}",
#         x="value",
#         color="year",
#         barmode="group",
#         histnorm="percent",
#         facet_col="dimension",
#         facet_col_wrap=3,
#         category_orders={"value":list(methods[method]["dims"]["labels"].values())},
#     )

#     fig.update_xaxes(col=3, showticklabels=True, visible=True)
#     fig.update_layout(legend=dict(xanchor="right", x=1, yanchor="bottom", y=0))

#     fig.show()
    
# [plot_year_histograms(t=t) for t in [0, 1]];

# %% [markdown]
# ## split data

# %%
# split train + test set
df_hip = df_hip_clean.query("t0_year != '2019/20'").drop(columns="t0_year")
df_hip_unseen = df_hip_clean.query("t0_year == '2019/20'").drop(columns="t0_year")

df_hip.sample(3)
# Out:
#        t0_age_band t0_gender t0_assisted t0_symptom_period  \
# 100832    70 to 79    female          no     6 to 10 years
# 109008    80 to 89      male          no      1 to 5 years
# 53672     60 to 69      male          no      1 to 5 years
#
#        t0_previous_surgery                    t0_living_arrangements  \
# 100832                  no  with partner / spouse / family / friends
# 109008                  no                                     alone
# 53672                   no  with partner / spouse / family / friends
#
#        t0_disability t0_heart_disease t0_high_bp t0_stroke  ...  \
# 100832           yes              NaN        yes       NaN  ...
# 109008           NaN              NaN        NaN       NaN  ...
# 53672             no              NaN        NaN       NaN  ...
#
#                     t1_ohs_washing          t1_ohs_transport  \
# 100832  sometimes or just at first  often, not just at first
# 109008                rarely/never              rarely/never
# 53672                 rarely/never              rarely/never
#
#                    t1_ohs_dressing           t1_ohs_shopping t1_ohs_walking  \
# 100832    often, not just at first  often, not just at first   rarely/never
# 109008  sometimes or just at first              rarely/never   rarely/never
# 53672                 rarely/never              rarely/never   rarely/never
#
#                     t1_ohs_limping               t1_ohs_stairs  \
# 100832  sometimes or just at first  sometimes or just at first
# 109008                rarely/never                rarely/never
# 53672                 rarely/never                rarely/never
#
#                    t1_ohs_standing   t1_ohs_work t1_ohs_score
# 100832  sometimes or just at first  rarely/never         35.0
# 109008                rarely/never  rarely/never         47.0
# 53672                 rarely/never  rarely/never         48.0
#
# [3 rows x 70 columns]

# %%
# create x, y
X = df_hip.filter(regex="t0")
# # regression:
# y = df_hip["t1_ohs_score"] - df_hip["t0_ohs_score"]

# classification
y_name = "t1_eq5d_discomfort"
y_labels = {k:v for k, v, in enumerate(df_hip[y_name].cat.categories)}
y = df_hip[y_name].cat.codes

# # make a smaller selection of our training data to play with
# X = X.iloc[:1000, :] # [0, 1, 2, 3, 4, -4, -3, -2, -1]]
# y = y.iloc[:1000]


# create train, test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
# # for total / Laurence
# y_temp = pd.cut(
#     df_hip["t1_ohs_score"],
#     bins=[0, 29, 39, 48],
#     labels=["severe-moderate", "mild", "satisfactory"],
#     include_lowest=True,
# )
# y_labels = {k: v for k, v, in enumerate(y_temp.cat.categories)}
# y = y_temp.cat.codes
# y_temp.value_counts() / len(y_temp)

# %% [markdown]
# ## make + train a simple pipeline

# %%
ct = ColumnTransformer(
    (
        ("numerical", StandardScaler(), KindSelector(kind="numerical")),
        (
            "categorical",
            OneHotEncoder(categories="categories", handle_unknown="ignore"),
            KindSelector(kind="categorical"),
        ),
        (
            "ordinal",
            OrdinalEncoder(categories="categories", handle_unknown="ignore"),
            KindSelector(kind="ordinal"),
        ),
    ),
    remainder="drop",
)

pl = Pipeline(
    (
        ("column_selector", "passthrough"),
        ("balancer", "passthrough"),
        ("by_column_kinds", ct),
        ("model", KNeighborsClassifier()),
    )
)

# train the pipeline/model
pl.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('column_selector', 'passthrough'), ('balancer', 'passthrough'),
#                 ('by_column_kinds',
#                  ColumnTransformer(transformers=(('numerical', StandardScaler(),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fe834f082b0>),
#                                                  ('categorical',
#                                                   OneHotEncoder(categories='categories',
#                                                                 handle_unknown='ignore'),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fe834f08370>),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(categories='categories',
#                                                                  handle_unknown='ignore'),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fe834f08430>)))),
#                 ('model', KNeighborsClassifier())])

# %%
get_feature_names(pl)
# Out:
# ['t0_eq5d_score',
#  't0_eqvas_score',
#  't0_ohs_score',
#  't0_gender_male',
#  't0_gender_female',
#  't0_assisted_yes',
#  't0_assisted_no',
#  't0_previous_surgery_yes',
#  't0_previous_surgery_no',
#  't0_living_arrangements_with partner / spouse / family / friends',
#  't0_living_arrangements_alone',
#  't0_living_arrangements_in a nursing home, hospital or other long-term care home',
#  't0_living_arrangements_other',
#  't0_disability_yes',
#  't0_disability_no',
#  't0_heart_disease_yes',
#  't0_high_bp_yes',
#  't0_stroke_yes',
#  't0_circulation_yes',
#  't0_lung_disease_yes',
#  't0_diabetes_yes',
#  't0_kidney_disease_yes',
#  't0_nervous_system_yes',
#  't0_liver_disease_yes',
#  't0_cancer_yes',
#  't0_depression_yes',
#  't0_arthritis_yes',
#  't0_age_band',
#  't0_symptom_period',
#  't0_eq5d_mobility',
#  't0_eq5d_self_care',
#  't0_eq5d_activity',
#  't0_eq5d_discomfort',
#  't0_eq5d_anxiety',
#  't0_ohs_pain',
#  't0_ohs_sudden_pain',
#  't0_ohs_night_pain',
#  't0_ohs_washing',
#  't0_ohs_transport',
#  't0_ohs_dressing',
#  't0_ohs_shopping',
#  't0_ohs_walking',
#  't0_ohs_limping',
#  't0_ohs_stairs',
#  't0_ohs_standing',
#  't0_ohs_work']

# %% [markdown]
# ## Gridsearch

# %%
class ColumnSelector(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        return X[self.columns]

# %%
subset = [col for col in X.columns if not "score" in col]

# %%
# %%time
# create parameter grid to search on 

# # standard same as pipeline
# param_grid = dict()

# tuning different hyper parameters on different models
param_grid = [
    {
        "column_selector": ["passthrough", ColumnSelector(subset)],
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True],
        "model": [BaggingClassifier()],
        "model__n_estimators": [100],
    },
    {
        "column_selector": ["passthrough", ColumnSelector(subset)],
        "balancer": ["passthrough"],
        "model": [BalancedBaggingClassifier()],
        "model__n_estimators": [100],
        "model__replacement": [True],
    },
    {
        "column_selector": ["passthrough", ColumnSelector(subset)],
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True],
        "model": [RandomForestClassifier()],
        "model__n_estimators": [100],
    },
    {
        "column_selector": ["passthrough", ColumnSelector(subset)],
        "balancer": ["passthrough"],
        "model": [BalancedRandomForestClassifier()],
        "model__n_estimators": [100],
        "model__replacement": [True],
        "model__class_weight": [None, "balanced", "balanced_subsample"],
    },
]


# # construct gridsearch

# # standard
GS = GridSearchCV(pl, param_grid=param_grid, scoring="roc_auc_ovo_weighted")

# # multiple
# GS = GridSearchCV(pl, param_grid=param_grid, scoring=["balanced_accuracy", "f1"], refit=False)

# train gridsearch
GS.fit(X_train, y_train)

# show results
pd.DataFrame(GS.cv_results_)\
    .filter(regex=r"^(?!.*(split|time)).*$")\
    .set_index("rank_test_score").sort_index()
# Out:
# CPU times: user 3min 55s, sys: 14.5 s, total: 4min 9s
# Wall time: 4min 16s
#                        param_balancer param_balancer__replacement  \
# rank_test_score
# 1                         passthrough                         NaN
# 2                         passthrough                         NaN
# 3                         passthrough                         NaN
# 4                         passthrough                         NaN
# 5                         passthrough                         NaN
# 6                         passthrough                         NaN
# 7                RandomUnderSampler()                        True
# 8                         passthrough                         NaN
# 9                         passthrough                         NaN
# 10               RandomUnderSampler()                        True
# 11               RandomUnderSampler()                        True
# 12               RandomUnderSampler()                        True
#
#                                              param_column_selector  \
# rank_test_score
# 1                                                      passthrough
# 2                                                      passthrough
# 3                ColumnSelector(columns=['t0_age_band', 't0_gen...
# 4                                                      passthrough
# 5                ColumnSelector(columns=['t0_age_band', 't0_gen...
# 6                ColumnSelector(columns=['t0_age_band', 't0_gen...
# 7                                                      passthrough
# 8                                                      passthrough
# 9                ColumnSelector(columns=['t0_age_band', 't0_gen...
# 10               ColumnSelector(columns=['t0_age_band', 't0_gen...
# 11                                                     passthrough
# 12               ColumnSelector(columns=['t0_age_band', 't0_gen...
#
#                                                        param_model  \
# rank_test_score
# 1                BalancedBaggingClassifier(n_estimators=100, re...
# 2                                 BalancedRandomForestClassifier()
# 3                BalancedBaggingClassifier(n_estimators=100, re...
# 4                                 BalancedRandomForestClassifier()
# 5                                 BalancedRandomForestClassifier()
# 6                                 BalancedRandomForestClassifier()
# 7                                         RandomForestClassifier()
# 8                                 BalancedRandomForestClassifier()
# 9                                 BalancedRandomForestClassifier()
# 10                                        RandomForestClassifier()
# 11                                             BaggingClassifier()
# 12                                             BaggingClassifier()
#
#                 param_model__n_estimators param_model__replacement  \
# rank_test_score
# 1                                     100                     True
# 2                                     100                     True
# 3                                     100                     True
# 4                                     100                     True
# 5                                     100                     True
# 6                                     100                     True
# 7                                     100                      NaN
# 8                                     100                     True
# 9                                     100                     True
# 10                                    100                      NaN
# 11                                    100                      NaN
# 12                                    100                      NaN
#
#                 param_model__class_weight  \
# rank_test_score
# 1                                     NaN
# 2                                    None
# 3                                     NaN
# 4                      balanced_subsample
# 5                      balanced_subsample
# 6                                    None
# 7                                     NaN
# 8                                balanced
# 9                                balanced
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
#
#                                                             params  \
# rank_test_score
# 1                {'balancer': 'passthrough', 'column_selector':...
# 2                {'balancer': 'passthrough', 'column_selector':...
# 3                {'balancer': 'passthrough', 'column_selector':...
# 4                {'balancer': 'passthrough', 'column_selector':...
# 5                {'balancer': 'passthrough', 'column_selector':...
# 6                {'balancer': 'passthrough', 'column_selector':...
# 7                {'balancer': RandomUnderSampler(), 'balancer__...
# 8                {'balancer': 'passthrough', 'column_selector':...
# 9                {'balancer': 'passthrough', 'column_selector':...
# 10               {'balancer': RandomUnderSampler(), 'balancer__...
# 11               {'balancer': RandomUnderSampler(), 'balancer__...
# 12               {'balancer': RandomUnderSampler(), 'balancer__...
#
#                  mean_test_score  std_test_score
# rank_test_score
# 1                       0.660208        0.003447
# 2                       0.658465        0.005514
# 3                       0.657442        0.002753
# 4                       0.656484        0.005446
# 5                       0.655138        0.006028
# 6                       0.655112        0.007363
# 7                       0.649938        0.005904
# 8                       0.648570        0.005274
# 9                       0.648075        0.005717
# 10                      0.645678        0.005073
# 11                      0.644655        0.004338
# 12                      0.635398        0.001379
