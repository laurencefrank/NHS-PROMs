# %% [markdown]
# # Refactored notebook for modelling

# %% [markdown]
# ## imports

# %%
import sys

sys.path.append("..")

import numpy as np
import pandas as pd
import warnings
import re
import plotly.express as px
import plotly.graph_objects as go

from NHS_PROMs.load_data import load_proms, structure_name
from NHS_PROMs.preprocess import filter_in_range, filter_in_labels, method_delta
from NHS_PROMs.utils import (
    downcast,
    map_labels,
    fillna_categories,
    pd_fit_resample,
    infer_categories_fit,
    KindSelector,
    get_feature_names,
    remove_categories,
)
from NHS_PROMs.data_dictionary import meta_dict, methods

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import make_column_selector

# from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import (
    ColumnTransformer,
    make_column_transformer,
    make_column_selector,
)
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingRegressor,
    BaggingClassifier,
)
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.inspection import permutation_importance
from sklearn import set_config

set_config(display="diagram")

from imblearn.ensemble import BalancedBaggingClassifier, BalancedRandomForestClassifier, EasyEnsembleClassifier
from imblearn.over_sampling import SMOTENC
from imblearn.pipeline import Pipeline, make_pipeline
from imblearn.under_sampling import RandomUnderSampler 

# use adjusted fillna which can cope with non-existing categories for CategoricalDtype
pd.core.frame.DataFrame.fillna = fillna_categories
# added a remove categories
pd.core.frame.Series.remove_categories = remove_categories
# enable autodetect of categories from CategoricalDtype by using "infer" for SMOTENC
SMOTENC.fit_resample = pd_fit_resample(SMOTENC.fit_resample)
# enable inference of categories for encoders from CategoricalDtype
OneHotEncoder.fit = infer_categories_fit(OneHotEncoder.fit)
OrdinalEncoder.fit = infer_categories_fit(OrdinalEncoder.fit)

# %% [markdown]
# ## load data
# General approach is not DRY for the sake of availability of having knee and hip df's always at hand, but also keep it readable (script-wise).

# %%
# load data + rename columns with structired name
# df_knee_raw = load_proms(part="knee").apply(downcast).rename(structure_name, axis=1)
df_hip_raw = load_proms(part="hip").apply(downcast).rename(structure_name, axis=1)

# get meta data for each
full_meta = {t + k: v for k, v in meta_dict.items() for t in ["t0_", "t1_"]}
hip_meta = {k: v for k, v in full_meta.items() if k in df_hip_raw.columns}

df_hip_raw.sample(3)
# Out:
#       t0_provider_code     t0_procedure  t0_revision_flag  t0_year  \
# 32930              RRJ  Hip Replacement                 0  2016/17
# 14590              RBA  Hip Replacement                 0  2017/18
# 6725             NT446  Hip Replacement                 0  2017/18
#
#       t0_age_band  t0_gender  t0_assisted  t0_assisted_by  t0_symptom_period  \
# 32930    60 to 69        1.0            2               0                  2
# 14590    50 to 59        2.0            2               0                  2
# 6725     70 to 79        1.0            2               0                  2
#
#        t0_previous_surgery  ...  t1_ohs_transport  t1_ohs_dressing  \
# 32930                    2  ...                 4                3
# 14590                    2  ...                 3                3
# 6725                     2  ...                 3                2
#
#        t1_ohs_shopping  t1_ohs_walking  t1_ohs_limping  t1_ohs_stairs  \
# 32930                4               4               4              4
# 14590                4               4               4              4
# 6725                 4               4               1              4
#
#        t1_ohs_standing  t1_ohs_work  t1_ohs_score  t1_ohs_predicted
# 32930                4            4          43.0         40.547779
# 14590                4            4          44.0         38.316620
# 6725                 4            4          42.0         41.998005
#
# [3 rows x 81 columns]

# %% [markdown]
# ## basic cleaning

# %%
# %%time

endings = (
    "code", # is a coded score and not of interest for the case
    "procedure", # is the same for the hip or knee set
    "revision_flag", # revisions are out of scope, filtered away, so same for all rows after that
    "assisted_by", # is the same for all records
    "profile", # is a coded score and not of interest for the case
    "predicted", # are predictions of other models that are not supposed to be used
)
cols2drop = [c for c in df_hip_raw.columns if c.endswith(endings)]

df_hip_clean = (
    df_hip_raw.apply(lambda s: filter_in_range(s, **hip_meta[s.name])) # filter in range numeric features
    .apply(lambda s: filter_in_labels(s, **hip_meta[s.name])) # filter in labels categorical features + ordinal if ordered
    .apply(lambda s: map_labels(s, **hip_meta[s.name])) # map the labels as values for readability
    .query("t0_revision_flag == 'no revision'") # drop revision cases
    .drop(columns=cols2drop) # drop not needed columns
    .reset_index(drop=True) # make index unique (prevent blow ups when joining)
)

# remove NaNs/missing/unknown from numerical and ordinal features
df_hip_clean = (
    df_hip_clean.apply(pd.Series.remove_categories, args=(["missing", "not known"],))
    .dropna(subset= KindSelector(kind="numerical")(df_hip_clean) + KindSelector(kind="ordinal")(df_hip_clean))
)

df_hip_clean.sample(3)
# Out:
# CPU times: user 932 ms, sys: 103 ms, total: 1.04 s
# Wall time: 1.04 s
#                         t0_year t0_age_band t0_gender t0_assisted  \
# 139135  April 2019 - April 2020    60 to 69      male          no
# 13864   April 2016 - April 2017    70 to 79    female          no
# 20746   April 2016 - April 2017    60 to 69    female         yes
#
#        t0_symptom_period t0_previous_surgery  \
# 139135  less than 1 year                  no
# 13864       1 to 5 years                  no
# 20746       1 to 5 years                  no
#
#                           t0_living_arrangements t0_disability  \
# 139135  with partner / spouse / family / friends           yes
# 13864   with partner / spouse / family / friends            no
# 20746                                      alone           NaN
#
#        t0_heart_disease t0_high_bp  ... t1_ohs_washing  \
# 139135              yes        yes  ...   rarely/never
# 13864               NaN        yes  ...   rarely/never
# 20746               NaN        NaN  ...   rarely/never
#
#                   t1_ohs_transport t1_ohs_dressing t1_ohs_shopping  \
# 139135                rarely/never    rarely/never    rarely/never
# 13864                 rarely/never    rarely/never    rarely/never
# 20746   sometimes or just at first    rarely/never    rarely/never
#
#        t1_ohs_walking t1_ohs_limping t1_ohs_stairs  \
# 139135   rarely/never   rarely/never  rarely/never
# 13864    rarely/never   rarely/never  rarely/never
# 20746    rarely/never   rarely/never  rarely/never
#
#                    t1_ohs_standing   t1_ohs_work t1_ohs_score
# 139135  sometimes or just at first  rarely/never         42.0
# 13864                 rarely/never  rarely/never         48.0
# 20746                 rarely/never  rarely/never         47.0
#
# [3 rows x 71 columns]

# %% [markdown]
# ### Explanation why we can drop years

# %%
# def plot_year_histograms(t=0, method="eq5d"):
    
#     facet_cols = ["_".join([f"t{t}", method, dim]) for dim in methods[method]["dims"]["names"]]

#     df_plot = (
#         df_hip_clean[["t0_year"] + facet_cols]
#         .set_index("t0_year")
#         .stack()
#         .reset_index()
#         .set_axis(["year", "dimension", "value"], axis=1)
#     )

#     fig = px.histogram(
#         df_plot,
#         title=f"Distributions of values over the years for method {method} at t{t}",
#         x="value",
#         color="year",
#         barmode="group",
#         histnorm="percent",
#         facet_col="dimension",
#         facet_col_wrap=3,
#         category_orders={"value":list(methods[method]["dims"]["labels"].values())},
#     )

#     fig.update_xaxes(col=3, showticklabels=True, visible=True)
#     fig.update_layout(legend=dict(xanchor="right", x=1, yanchor="bottom", y=0))

#     fig.show()
    
# [plot_year_histograms(t=t) for t in [0, 1]];

# %% [markdown]
# ## split data

# %%
# split train + test set
df_hip = df_hip_clean.query("t0_year != '2019/20'").drop(columns="t0_year")
df_hip_unseen = df_hip_clean.query("t0_year == '2019/20'").drop(columns="t0_year")

df_hip.sample(3)
# Out:
#        t0_age_band t0_gender t0_assisted   t0_symptom_period  \
# 12081     70 to 79    female          no    less than 1 year
# 12687     70 to 79    female          no        1 to 5 years
# 108404    40 to 49    female          no  more than 10 years
#
#        t0_previous_surgery                    t0_living_arrangements  \
# 12081                  yes                                     alone
# 12687                   no  with partner / spouse / family / friends
# 108404                  no  with partner / spouse / family / friends
#
#        t0_disability t0_heart_disease t0_high_bp t0_stroke  ...  \
# 12081             no              NaN        yes       NaN  ...
# 12687             no              NaN        yes       NaN  ...
# 108404           yes              NaN        NaN       NaN  ...
#
#                     t1_ohs_washing            t1_ohs_transport  \
# 12081                 rarely/never                rarely/never
# 12687   sometimes or just at first    often, not just at first
# 108404  sometimes or just at first  sometimes or just at first
#
#                    t1_ohs_dressing             t1_ohs_shopping t1_ohs_walking  \
# 12081   sometimes or just at first                rarely/never   rarely/never
# 12687             most of the time  sometimes or just at first   rarely/never
# 108404  sometimes or just at first    often, not just at first   rarely/never
#
#                     t1_ohs_limping               t1_ohs_stairs  \
# 12081                 rarely/never                rarely/never
# 12687   sometimes or just at first  sometimes or just at first
# 108404            most of the time                rarely/never
#
#                    t1_ohs_standing                 t1_ohs_work t1_ohs_score
# 12081                 rarely/never                rarely/never         47.0
# 12687   sometimes or just at first  sometimes or just at first         34.0
# 108404  sometimes or just at first  sometimes or just at first         36.0
#
# [3 rows x 70 columns]

# %%
# create x, y
X = df_hip.filter(regex="t0")
# # regression:
# y = df_hip["t1_ohs_score"] - df_hip["t0_ohs_score"]

# classification
y_name = "t1_eq5d_self_care"
y_labels = {k:v for k, v, in enumerate(df_hip[y_name].cat.categories)}
y = df_hip[y_name].cat.codes

# # make a smaller selection of our training data to play with
# X = X.iloc[:1000, :] # [0, 1, 2, 3, 4, -4, -3, -2, -1]]
# y = y.iloc[:1000]


# create train, test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
# # for total / Laurence
# y_temp = pd.cut(
#     df_hip["t1_ohs_score"],
#     bins=[0, 29, 39, 48],
#     labels=["severe-moderate", "mild", "satisfactory"],
#     include_lowest=True,
# )
# y_labels = {k: v for k, v, in enumerate(y_temp.cat.categories)}
# y = y_temp.cat.codes
# y_temp.value_counts() / len(y_temp)

# %% [markdown]
# ## make + train a simple pipeline

# %%
ct = ColumnTransformer(
    (
        ("numerical", StandardScaler(), KindSelector(kind="numerical")),
        (
            "categorical",
            OneHotEncoder(categories="categories", handle_unknown="ignore"),
            KindSelector(kind="categorical"),
        ),
        (
            "ordinal",
            OrdinalEncoder(categories="categories", handle_unknown="ignore"),
            KindSelector(kind="ordinal"),
        ),
    ),
    remainder="drop",
)

pl = Pipeline(
    (
        ("balancer", "passthrough"),
        ("by_column_kinds", ct),
        ("model", KNeighborsClassifier()),
    )
)

# train the pipeline/model
pl.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('balancer', 'passthrough'),
#                 ('by_column_kinds',
#                  ColumnTransformer(transformers=(('numerical', StandardScaler(),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fec19e25c70>),
#                                                  ('categorical',
#                                                   OneHotEncoder(categories='categories',
#                                                                 handle_unknown='ignore'),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fec19e25d30>),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(categories='categories',
#                                                                  handle_unknown='ignore'),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fec19e25df0>)))),
#                 ('model', KNeighborsClassifier())])

# %%
get_feature_names(pl)
# Out:
# ['t0_eq5d_score',
#  't0_eqvas_score',
#  't0_ohs_score',
#  't0_gender_male',
#  't0_gender_female',
#  't0_assisted_yes',
#  't0_assisted_no',
#  't0_previous_surgery_yes',
#  't0_previous_surgery_no',
#  't0_living_arrangements_with partner / spouse / family / friends',
#  't0_living_arrangements_alone',
#  't0_living_arrangements_in a nursing home, hospital or other long-term care home',
#  't0_living_arrangements_other',
#  't0_disability_yes',
#  't0_disability_no',
#  't0_heart_disease_yes',
#  't0_high_bp_yes',
#  't0_stroke_yes',
#  't0_circulation_yes',
#  't0_lung_disease_yes',
#  't0_diabetes_yes',
#  't0_kidney_disease_yes',
#  't0_nervous_system_yes',
#  't0_liver_disease_yes',
#  't0_cancer_yes',
#  't0_depression_yes',
#  't0_arthritis_yes',
#  't0_age_band',
#  't0_symptom_period',
#  't0_eq5d_mobility',
#  't0_eq5d_self_care',
#  't0_eq5d_activity',
#  't0_eq5d_discomfort',
#  't0_eq5d_anxiety',
#  't0_ohs_pain',
#  't0_ohs_sudden_pain',
#  't0_ohs_night_pain',
#  't0_ohs_washing',
#  't0_ohs_transport',
#  't0_ohs_dressing',
#  't0_ohs_shopping',
#  't0_ohs_walking',
#  't0_ohs_limping',
#  't0_ohs_stairs',
#  't0_ohs_standing',
#  't0_ohs_work']

# %% [markdown]
# ## Gridsearch

# %%
# %%time
# create parameter grid to search on 

# # standard same as pipeline
# param_grid = dict()

# tuning different hyper parameters on different models
param_grid = [
    {
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True, False],
        "model": [BaggingClassifier()],
        "model__n_estimators": [10, 100],
    },
    {
        "balancer": ["passthrough"],
        "model": [BalancedBaggingClassifier()],
        "model__n_estimators": [10, 100],
        "model__replacement": [True, False],
    },
    {
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True, False],
        "model": [RandomForestClassifier()],
        "model__n_estimators": [10, 100],
    },
    {
        "balancer": ["passthrough"],
        "model": [BalancedRandomForestClassifier()],
        "model__n_estimators": [10, 100],
        "model__replacement": [True, False],
        "model__class_weight": [None, "balanced", "balanced_subsample"],
    },
    {
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True, False],
        "model": [AdaBoostClassifier()],
        "model__n_estimators": [10, 100],
    },
    {
        "balancer": ["passthrough"],
        "model": [EasyEnsembleClassifier()],
        "model__n_estimators": [10, 100],
        "model__replacement": [True, False],
    },
]


# # construct gridsearch

# # standard
GS = GridSearchCV(pl, param_grid=param_grid, scoring="roc_auc_ovo_weighted")

# # multiple
# GS = GridSearchCV(pl, param_grid=param_grid, scoring=["balanced_accuracy", "f1"], refit=False)

# train gridsearch
GS.fit(X_train, y_train)

# show results
pd.DataFrame(GS.cv_results_)\
    .filter(regex=r"^(?!.*(split|time)).*$")\
    .set_index("rank_test_score").sort_index()
# Out:
# CPU times: user 10min 32s, sys: 23.6 s, total: 10min 56s
# Wall time: 23min 20s
#                        param_balancer param_balancer__replacement  \
# rank_test_score
# 1                         passthrough                         NaN
# 2                         passthrough                         NaN
# 3                         passthrough                         NaN
# 4                         passthrough                         NaN
# 5                         passthrough                         NaN
# 6                         passthrough                         NaN
# 7                         passthrough                         NaN
# 8                         passthrough                         NaN
# 9                RandomUnderSampler()                       False
# 10               RandomUnderSampler()                        True
# 11               RandomUnderSampler()                       False
# 12               RandomUnderSampler()                       False
# 13               RandomUnderSampler()                        True
# 14               RandomUnderSampler()                        True
# 15                        passthrough                         NaN
# 16                        passthrough                         NaN
# 17                        passthrough                         NaN
# 18                        passthrough                         NaN
# 19                        passthrough                         NaN
# 20                        passthrough                         NaN
# 21                        passthrough                         NaN
# 22                        passthrough                         NaN
# 23                        passthrough                         NaN
# 24                        passthrough                         NaN
# 25                        passthrough                         NaN
# 26               RandomUnderSampler()                        True
# 27               RandomUnderSampler()                       False
# 28               RandomUnderSampler()                       False
# 29                        passthrough                         NaN
# 30               RandomUnderSampler()                        True
# 31               RandomUnderSampler()                       False
# 32               RandomUnderSampler()                        True
#
#                                                        param_model  \
# rank_test_score
# 1                BalancedBaggingClassifier(n_estimators=100, re...
# 2                BalancedBaggingClassifier(n_estimators=100, re...
# 3                                 BalancedRandomForestClassifier()
# 4                                 BalancedRandomForestClassifier()
# 5                                 BalancedRandomForestClassifier()
# 6                                 BalancedRandomForestClassifier()
# 7                                 BalancedRandomForestClassifier()
# 8                                 BalancedRandomForestClassifier()
# 9                                         RandomForestClassifier()
# 10                                        RandomForestClassifier()
# 11                                             BaggingClassifier()
# 12                                            AdaBoostClassifier()
# 13                                             BaggingClassifier()
# 14                                            AdaBoostClassifier()
# 15               BalancedBaggingClassifier(n_estimators=100, re...
# 16               BalancedBaggingClassifier(n_estimators=100, re...
# 17                                        EasyEnsembleClassifier()
# 18                                        EasyEnsembleClassifier()
# 19                                BalancedRandomForestClassifier()
# 20                                BalancedRandomForestClassifier()
# 21                                        EasyEnsembleClassifier()
# 22                                        EasyEnsembleClassifier()
# 23                                BalancedRandomForestClassifier()
# 24                                BalancedRandomForestClassifier()
# 25                                BalancedRandomForestClassifier()
# 26                                        RandomForestClassifier()
# 27                                             BaggingClassifier()
# 28                                        RandomForestClassifier()
# 29                                BalancedRandomForestClassifier()
# 30                                             BaggingClassifier()
# 31                                            AdaBoostClassifier()
# 32                                            AdaBoostClassifier()
#
#                 param_model__n_estimators param_model__replacement  \
# rank_test_score
# 1                                     100                     True
# 2                                     100                    False
# 3                                     100                    False
# 4                                     100                    False
# 5                                     100                     True
# 6                                     100                     True
# 7                                     100                    False
# 8                                     100                     True
# 9                                     100                      NaN
# 10                                    100                      NaN
# 11                                    100                      NaN
# 12                                     10                      NaN
# 13                                    100                      NaN
# 14                                     10                      NaN
# 15                                     10                    False
# 16                                     10                     True
# 17                                    100                     True
# 18                                    100                    False
# 19                                     10                     True
# 20                                     10                    False
# 21                                     10                     True
# 22                                     10                    False
# 23                                     10                    False
# 24                                     10                     True
# 25                                     10                     True
# 26                                     10                      NaN
# 27                                     10                      NaN
# 28                                     10                      NaN
# 29                                     10                    False
# 30                                     10                      NaN
# 31                                    100                      NaN
# 32                                    100                      NaN
#
#                 param_model__class_weight  \
# rank_test_score
# 1                                     NaN
# 2                                     NaN
# 3                      balanced_subsample
# 4                                    None
# 5                                    None
# 6                      balanced_subsample
# 7                                balanced
# 8                                balanced
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                     balanced_subsample
# 20                                   None
# 21                                    NaN
# 22                                    NaN
# 23                     balanced_subsample
# 24                                   None
# 25                               balanced
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                               balanced
# 30                                    NaN
# 31                                    NaN
# 32                                    NaN
#
#                                                             params  \
# rank_test_score
# 1                {'balancer': 'passthrough', 'model': BalancedB...
# 2                {'balancer': 'passthrough', 'model': BalancedB...
# 3                {'balancer': 'passthrough', 'model': BalancedR...
# 4                {'balancer': 'passthrough', 'model': BalancedR...
# 5                {'balancer': 'passthrough', 'model': BalancedR...
# 6                {'balancer': 'passthrough', 'model': BalancedR...
# 7                {'balancer': 'passthrough', 'model': BalancedR...
# 8                {'balancer': 'passthrough', 'model': BalancedR...
# 9                {'balancer': RandomUnderSampler(), 'balancer__...
# 10               {'balancer': RandomUnderSampler(), 'balancer__...
# 11               {'balancer': RandomUnderSampler(), 'balancer__...
# 12               {'balancer': RandomUnderSampler(), 'balancer__...
# 13               {'balancer': RandomUnderSampler(), 'balancer__...
# 14               {'balancer': RandomUnderSampler(), 'balancer__...
# 15               {'balancer': 'passthrough', 'model': BalancedB...
# 16               {'balancer': 'passthrough', 'model': BalancedB...
# 17               {'balancer': 'passthrough', 'model': EasyEnsem...
# 18               {'balancer': 'passthrough', 'model': EasyEnsem...
# 19               {'balancer': 'passthrough', 'model': BalancedR...
# 20               {'balancer': 'passthrough', 'model': BalancedR...
# 21               {'balancer': 'passthrough', 'model': EasyEnsem...
# 22               {'balancer': 'passthrough', 'model': EasyEnsem...
# 23               {'balancer': 'passthrough', 'model': BalancedR...
# 24               {'balancer': 'passthrough', 'model': BalancedR...
# 25               {'balancer': 'passthrough', 'model': BalancedR...
# 26               {'balancer': RandomUnderSampler(), 'balancer__...
# 27               {'balancer': RandomUnderSampler(), 'balancer__...
# 28               {'balancer': RandomUnderSampler(), 'balancer__...
# 29               {'balancer': 'passthrough', 'model': BalancedR...
# 30               {'balancer': RandomUnderSampler(), 'balancer__...
# 31               {'balancer': RandomUnderSampler(), 'balancer__...
# 32               {'balancer': RandomUnderSampler(), 'balancer__...
#
#                  mean_test_score  std_test_score
# rank_test_score
# 1                       0.805581        0.009163
# 2                       0.804185        0.009195
# 3                       0.801977        0.007976
# 4                       0.801354        0.006305
# 5                       0.801134        0.007533
# 6                       0.798384        0.009276
# 7                       0.792429        0.009553
# 8                       0.789595        0.007730
# 9                       0.780167        0.003012
# 10                      0.779232        0.007123
# 11                      0.778917        0.006049
# 12                      0.770942        0.012906
# 13                      0.767488        0.012110
# 14                      0.766187        0.021415
# 15                      0.764601        0.012608
# 16                      0.763225        0.011641
# 17                      0.762637        0.008564
# 18                      0.760794        0.007540
# 19                      0.756910        0.008223
# 20                      0.756693        0.006617
# 21                      0.755938        0.011446
# 22                      0.755722        0.005019
# 23                      0.755528        0.009290
# 24                      0.752130        0.006827
# 25                      0.752029        0.015342
# 26                      0.750162        0.015019
# 27                      0.747619        0.007314
# 28                      0.747182        0.016294
# 29                      0.745354        0.006487
# 30                      0.743398        0.008745
# 31                      0.725784        0.010905
# 32                      0.719850        0.010370
