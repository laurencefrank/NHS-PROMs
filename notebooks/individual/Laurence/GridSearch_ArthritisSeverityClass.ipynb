# %% [markdown]
# # Refactored notebook for modelling

# %% [markdown]
# ## imports

# %%
import sys

sys.path.append("..")

import numpy as np
import pandas as pd
import warnings
import re
import plotly.express as px
import plotly.graph_objects as go

from NHS_PROMs.load_data import load_proms, structure_name
from NHS_PROMs.preprocess import filter_in_range, filter_in_labels, method_delta
from NHS_PROMs.utils import (
    downcast,
    map_labels,
    fillna_categories,
    pd_fit_resample,
    infer_categories_fit,
    KindSelector,
    get_feature_names,
    remove_categories,
)
from NHS_PROMs.data_dictionary import meta_dict, methods

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import make_column_selector

# from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import (
    ColumnTransformer,
    make_column_transformer,
    make_column_selector,
)
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingRegressor,
    BaggingClassifier,
)
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.inspection import permutation_importance
from sklearn import set_config

set_config(display="diagram")

from imblearn.ensemble import BalancedBaggingClassifier, BalancedRandomForestClassifier, EasyEnsembleClassifier
from imblearn.over_sampling import SMOTENC
from imblearn.pipeline import Pipeline, make_pipeline
from imblearn.under_sampling import RandomUnderSampler 

# use adjusted fillna which can cope with non-existing categories for CategoricalDtype
pd.core.frame.DataFrame.fillna = fillna_categories
# added a remove categories
pd.core.frame.Series.remove_categories = remove_categories
# enable autodetect of categories from CategoricalDtype by using "infer" for SMOTENC
SMOTENC.fit_resample = pd_fit_resample(SMOTENC.fit_resample)
# enable inference of categories for encoders from CategoricalDtype
OneHotEncoder.fit = infer_categories_fit(OneHotEncoder.fit)
OrdinalEncoder.fit = infer_categories_fit(OrdinalEncoder.fit)

SEED = 42

# %% [markdown]
# ## load data
# General approach is not DRY for the sake of availability of having knee and hip df's always at hand, but also keep it readable (script-wise).

# %%
# load data + rename columns with structired name
# df_knee_raw = load_proms(part="knee").apply(downcast).rename(structure_name, axis=1)
df_hip_raw = load_proms(part="hip").apply(downcast).rename(structure_name, axis=1)

# get meta data for each
full_meta = {t + k: v for k, v in meta_dict.items() for t in ["t0_", "t1_"]}
hip_meta = {k: v for k, v in full_meta.items() if k in df_hip_raw.columns}

df_hip_raw.sample(3)
# Out:
#       t0_provider_code     t0_procedure  t0_revision_flag  t0_year  \
# 7005             NT457  Hip Replacement                 0  2017/18
# 29121              RNA  Hip Replacement                 0  2016/17
# 6940             NT450  Hip Replacement                 0  2017/18
#
#       t0_age_band  t0_gender  t0_assisted  t0_assisted_by  t0_symptom_period  \
# 7005     50 to 59        1.0            2               0                  1
# 29121    70 to 79        1.0            2               0                  2
# 6940     70 to 79        2.0            2               0                  2
#
#        t0_previous_surgery  ...  t1_ohs_transport  t1_ohs_dressing  \
# 7005                     2  ...                 4                4
# 29121                    2  ...                 4                2
# 6940                     2  ...                 4                2
#
#        t1_ohs_shopping  t1_ohs_walking  t1_ohs_limping  t1_ohs_stairs  \
# 7005                 4               4               4              4
# 29121                0               0               4              4
# 6940                 4               4               4              2
#
#        t1_ohs_standing  t1_ohs_work  t1_ohs_score  t1_ohs_predicted
# 7005                 4            4          48.0         43.657093
# 29121                4            3          36.0         36.462620
# 6940                 4            4          43.0         38.455685
#
# [3 rows x 81 columns]

# %% [markdown]
# ## basic cleaning

# %%
# %%time

endings = (
    "code", # is a coded score and not of interest for the case
    "procedure", # is the same for the hip or knee set
    "revision_flag", # revisions are out of scope, filtered away, so same for all rows after that
    "assisted_by", # is the same for all records
    "profile", # is a coded score and not of interest for the case
    "predicted", # are predictions of other models that are not supposed to be used
)
cols2drop = [c for c in df_hip_raw.columns if c.endswith(endings)]

df_hip_clean = (
    df_hip_raw.apply(lambda s: filter_in_range(s, **hip_meta[s.name])) # filter in range numeric features
    .apply(lambda s: filter_in_labels(s, **hip_meta[s.name])) # filter in labels categorical features + ordinal if ordered
    .apply(lambda s: map_labels(s, **hip_meta[s.name])) # map the labels as values for readability
    .query("t0_revision_flag == 'no revision'") # drop revision cases
    .drop(columns=cols2drop) # drop not needed columns
    .reset_index(drop=True) # make index unique (prevent blow ups when joining)
)

# remove NaNs/missing/unknown from numerical and ordinal features
df_hip_clean = (
    df_hip_clean.apply(pd.Series.remove_categories, args=(["missing", "not known"],))
    .dropna(subset= KindSelector(kind="numerical")(df_hip_clean) + KindSelector(kind="ordinal")(df_hip_clean))
)

df_hip_clean.sample(3)
# Out:
# CPU times: user 630 ms, sys: 51.8 ms, total: 682 ms
# Wall time: 680 ms
#                        t0_year t0_age_band t0_gender t0_assisted  \
# 89607  April 2018 - April 2019    80 to 89    female         yes
# 96860  April 2018 - April 2019    80 to 89    female         yes
# 53436  April 2017 - April 2018    70 to 79      male          no
#
#       t0_symptom_period t0_previous_surgery  \
# 89607     6 to 10 years                  no
# 96860      1 to 5 years                  no
# 53436     6 to 10 years                  no
#
#                          t0_living_arrangements t0_disability  \
# 89607                                     alone           yes
# 96860  with partner / spouse / family / friends           yes
# 53436  with partner / spouse / family / friends            no
#
#       t0_heart_disease t0_high_bp  ...    t1_ohs_washing  \
# 89607              yes        NaN  ...  most of the time
# 96860              NaN        NaN  ...      rarely/never
# 53436              NaN        NaN  ...      rarely/never
#
#                  t1_ohs_transport             t1_ohs_dressing  \
# 89607    often, not just at first            most of the time
# 96860  sometimes or just at first    often, not just at first
# 53436                rarely/never  sometimes or just at first
#
#        t1_ohs_shopping              t1_ohs_walking  \
# 89607  all of the time    often, not just at first
# 96860  all of the time  sometimes or just at first
# 53436     rarely/never                rarely/never
#
#                    t1_ohs_limping               t1_ohs_stairs  \
# 89607            most of the time  sometimes or just at first
# 96860  sometimes or just at first    often, not just at first
# 53436                rarely/never                rarely/never
#
#                 t1_ohs_standing                 t1_ohs_work t1_ohs_score
# 89607  often, not just at first            most of the time         20.0
# 96860              rarely/never  sometimes or just at first         35.0
# 53436              rarely/never                rarely/never         46.0
#
# [3 rows x 71 columns]

# %% [markdown]
# ### Explanation why we can drop years

# %%
# def plot_year_histograms(t=0, method="eq5d"):
    
#     facet_cols = ["_".join([f"t{t}", method, dim]) for dim in methods[method]["dims"]["names"]]

#     df_plot = (
#         df_hip_clean[["t0_year"] + facet_cols]
#         .set_index("t0_year")
#         .stack()
#         .reset_index()
#         .set_axis(["year", "dimension", "value"], axis=1)
#     )

#     fig = px.histogram(
#         df_plot,
#         title=f"Distributions of values over the years for method {method} at t{t}",
#         x="value",
#         color="year",
#         barmode="group",
#         histnorm="percent",
#         facet_col="dimension",
#         facet_col_wrap=3,
#         category_orders={"value":list(methods[method]["dims"]["labels"].values())},
#     )

#     fig.update_xaxes(col=3, showticklabels=True, visible=True)
#     fig.update_layout(legend=dict(xanchor="right", x=1, yanchor="bottom", y=0))

#     fig.show()
    
# [plot_year_histograms(t=t) for t in [0, 1]];

# %% [markdown]
# ## split data

# %%
# split train + test set
df_hip = df_hip_clean.query("t0_year != '2019/20'").drop(columns="t0_year")
df_hip_unseen = df_hip_clean.query("t0_year == '2019/20'").drop(columns="t0_year")

df_hip.sample(3)
# Out:
#       t0_age_band t0_gender t0_assisted t0_symptom_period t0_previous_surgery  \
# 64009    70 to 79      male          no      1 to 5 years                  no
# 91360    70 to 79      male          no      1 to 5 years                  no
# 71968    80 to 89    female         yes      1 to 5 years                  no
#
#                          t0_living_arrangements t0_disability  \
# 64009  with partner / spouse / family / friends            no
# 91360  with partner / spouse / family / friends           yes
# 71968                                     alone           yes
#
#       t0_heart_disease t0_high_bp t0_stroke  ...   t1_ohs_washing  \
# 64009              NaN        NaN       NaN  ...     rarely/never
# 91360              NaN        NaN       NaN  ...     rarely/never
# 71968              yes        yes       NaN  ...  all of the time
#
#                  t1_ohs_transport             t1_ohs_dressing  \
# 64009  sometimes or just at first  sometimes or just at first
# 91360  sometimes or just at first                rarely/never
# 71968  sometimes or just at first             all of the time
#
#        t1_ohs_shopping t1_ohs_walking              t1_ohs_limping  \
# 64009     rarely/never   rarely/never  sometimes or just at first
# 91360     rarely/never   rarely/never  sometimes or just at first
# 71968  all of the time   rarely/never                rarely/never
#
#                     t1_ohs_stairs             t1_ohs_standing  \
# 64009  sometimes or just at first  sometimes or just at first
# 91360  sometimes or just at first                rarely/never
# 71968             all of the time                rarely/never
#
#                       t1_ohs_work t1_ohs_score
# 64009  sometimes or just at first         39.0
# 91360                rarely/never         44.0
# 71968                rarely/never         31.0
#
# [3 rows x 70 columns]

# %%
# create x, y
X = df_hip.filter(regex="t0")
# # regression:
# y = df_hip["t1_ohs_score"] - df_hip["t0_ohs_score"]

# classification
#y_name = "t1_eq5d_discomfort"
#y_labels = {k:v for k, v, in enumerate(df_hip[y_name].cat.categories)}
#y = df_hip[y_name].cat.codes

y_temp = pd.cut(
     df_hip["t1_ohs_score"],
     bins=[0, 29, 39, 48],
     labels=["severe-moderate", "mild", "satisfactory"],
     include_lowest=True,
     )
    
y_labels = {k: v for k, v, in enumerate(y_temp.cat.categories)}
y = y_temp.cat.codes
#y_temp.value_counts() / len(y_temp)

# # make a smaller selection of our training data to play with
# X = X.iloc[:1000, :] # [0, 1, 2, 3, 4, -4, -3, -2, -1]]
# y = y.iloc[:1000]


# create train, test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=SEED)

# %%
y_temp.value_counts() / len(y_temp)
# Out:
# satisfactory       0.659223
# mild               0.225011
# severe-moderate    0.115766
# Name: t1_ohs_score, dtype: float64

# %%
# # for total / Laurence
# y_temp = pd.cut(
#     df_hip["t1_ohs_score"],
#     bins=[0, 29, 39, 48],
#     labels=["severe-moderate", "mild", "satisfactory"],
#     include_lowest=True,
# )
# y_labels = {k: v for k, v, in enumerate(y_temp.cat.categories)}
# y = y_temp.cat.codes
# y_temp.value_counts() / len(y_temp)

# %% [markdown]
# ## make + train a simple pipeline

# %%
ct = ColumnTransformer(
    (
        ("numerical", StandardScaler(), KindSelector(kind="numerical")),
        (
            "categorical",
            OneHotEncoder(categories="categories", handle_unknown="ignore"),
            KindSelector(kind="categorical"),
        ),
        (
            "ordinal",
            OrdinalEncoder(categories="categories", handle_unknown="ignore"),
            KindSelector(kind="ordinal"),
        ),
    ),
    remainder="drop",
)

pl = Pipeline(
    (
        ("balancer", "passthrough"),
        ("by_column_kinds", ct),
        ("model", KNeighborsClassifier()),
    )
)

# train the pipeline/model
pl.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('balancer', 'passthrough'),
#                 ('by_column_kinds',
#                  ColumnTransformer(transformers=(('numerical', StandardScaler(),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fd02a2bf700>),
#                                                  ('categorical',
#                                                   OneHotEncoder(categories='categories',
#                                                                 handle_unknown='ignore'),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fd02a2bf880>),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(categories='categories',
#                                                                  handle_unknown='ignore'),
#                                                   <NHS_PROMs.utils.KindSelector object at 0x7fd0297c3ca0>)))),
#                 ('model', KNeighborsClassifier())])

# %%
get_feature_names(pl)
# Out:
# ['t0_eq5d_score',
#  't0_eqvas_score',
#  't0_ohs_score',
#  't0_gender_male',
#  't0_gender_female',
#  't0_assisted_yes',
#  't0_assisted_no',
#  't0_previous_surgery_yes',
#  't0_previous_surgery_no',
#  't0_living_arrangements_with partner / spouse / family / friends',
#  't0_living_arrangements_alone',
#  't0_living_arrangements_in a nursing home, hospital or other long-term care home',
#  't0_living_arrangements_other',
#  't0_disability_yes',
#  't0_disability_no',
#  't0_heart_disease_yes',
#  't0_high_bp_yes',
#  't0_stroke_yes',
#  't0_circulation_yes',
#  't0_lung_disease_yes',
#  't0_diabetes_yes',
#  't0_kidney_disease_yes',
#  't0_nervous_system_yes',
#  't0_liver_disease_yes',
#  't0_cancer_yes',
#  't0_depression_yes',
#  't0_arthritis_yes',
#  't0_age_band',
#  't0_symptom_period',
#  't0_eq5d_mobility',
#  't0_eq5d_self_care',
#  't0_eq5d_activity',
#  't0_eq5d_discomfort',
#  't0_eq5d_anxiety',
#  't0_ohs_pain',
#  't0_ohs_sudden_pain',
#  't0_ohs_night_pain',
#  't0_ohs_washing',
#  't0_ohs_transport',
#  't0_ohs_dressing',
#  't0_ohs_shopping',
#  't0_ohs_walking',
#  't0_ohs_limping',
#  't0_ohs_stairs',
#  't0_ohs_standing',
#  't0_ohs_work']

# %% [markdown]
# ## Gridsearch

# %% [markdown]
# Test one model

# %%
# %%time
# create parameter grid to search on 

# # standard same as pipeline
# param_grid = dict()

# tuning different hyper parameters on different models
param_grid = [
    {
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True, False],
        "model": [BaggingClassifier()],
        "model__n_estimators": [10, 100],
    }
]

# # construct gridsearch

# # standard
GS = GridSearchCV(pl, param_grid=param_grid, scoring="roc_auc_ovo_weighted")

# # multiple
# GS = GridSearchCV(pl, param_grid=param_grid, scoring=["balanced_accuracy", "f1"], refit=False)

# train gridsearch
GS.fit(X_train, y_train)

# show results
pd.DataFrame(GS.cv_results_)\
    .filter(regex=r"^(?!.*(split|time)).*$")\
    .set_index("rank_test_score").sort_index()
# Out:
# CPU times: user 1min 51s, sys: 1.07 s, total: 1min 52s
# Wall time: 1min 52s
#                                        param_balancer  \
# rank_test_score
# 1                RandomUnderSampler(replacement=True)
# 2                RandomUnderSampler(replacement=True)
# 3                RandomUnderSampler(replacement=True)
# 4                RandomUnderSampler(replacement=True)
#
#                 param_balancer__replacement  \
# rank_test_score
# 1                                      True
# 2                                     False
# 3                                     False
# 4                                      True
#
#                                          param_model  \
# rank_test_score
# 1                BaggingClassifier(n_estimators=100)
# 2                BaggingClassifier(n_estimators=100)
# 3                BaggingClassifier(n_estimators=100)
# 4                BaggingClassifier(n_estimators=100)
#
#                 param_model__n_estimators  \
# rank_test_score
# 1                                     100
# 2                                     100
# 3                                      10
# 4                                      10
#
#                                                             params  \
# rank_test_score
# 1                {'balancer': RandomUnderSampler(replacement=Tr...
# 2                {'balancer': RandomUnderSampler(replacement=Tr...
# 3                {'balancer': RandomUnderSampler(replacement=Tr...
# 4                {'balancer': RandomUnderSampler(replacement=Tr...
#
#                  mean_test_score  std_test_score
# rank_test_score
# 1                       0.661950        0.004840
# 2                       0.661828        0.003961
# 3                       0.628779        0.004766
# 4                       0.628043        0.004812

# %%
# %%time
# create parameter grid to search on 

# # standard same as pipeline
# param_grid = dict()

# tuning different hyper parameters on different models
param_grid = [
    {
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True, False],
        "model": [BaggingClassifier()],
        "model__n_estimators": [10, 100],
    },
    {
        "balancer": ["passthrough"],
        "model": [BalancedBaggingClassifier()],
        "model__n_estimators": [10, 100],
        "model__replacement": [True, False],
    },
    {
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True, False],
        "model": [RandomForestClassifier()],
        "model__n_estimators": [10, 100],
    },
    {
        "balancer": ["passthrough"],
        "model": [BalancedRandomForestClassifier()],
        "model__n_estimators": [10, 100],
        "model__replacement": [True, False],
        "model__class_weight": [None, "balanced", "balanced_subsample"],
    },
    {
        "balancer": [RandomUnderSampler()],
        "balancer__replacement": [True, False],
        "model": [AdaBoostClassifier()],
        "model__n_estimators": [10, 100],
    },
    {
        "balancer": ["passthrough"],
        "model": [EasyEnsembleClassifier()],
        "model__n_estimators": [10, 100],
        "model__replacement": [True, False],
    },
]


# # construct gridsearch

# # standard
GS = GridSearchCV(pl, param_grid=param_grid, scoring="roc_auc_ovo_weighted")

# # multiple
# GS = GridSearchCV(pl, param_grid=param_grid, scoring=["balanced_accuracy", "f1"], refit=False)

# train gridsearch
GS.fit(X_train, y_train)

# show results
pd.DataFrame(GS.cv_results_)\
    .filter(regex=r"^(?!.*(split|time)).*$")\
    .set_index("rank_test_score").sort_index()
# Out:
# CPU times: user 21min 40s, sys: 26.5 s, total: 22min 6s
# Wall time: 22min 6s
#                        param_balancer param_balancer__replacement  \
# rank_test_score
# 1                         passthrough                         NaN
# 2                         passthrough                         NaN
# 3                         passthrough                         NaN
# 4                         passthrough                         NaN
# 5                RandomUnderSampler()                       False
# 6                RandomUnderSampler()                        True
# 7                         passthrough                         NaN
# 8                         passthrough                         NaN
# 9                         passthrough                         NaN
# 10                        passthrough                         NaN
# 11                        passthrough                         NaN
# 12                        passthrough                         NaN
# 13                        passthrough                         NaN
# 14               RandomUnderSampler()                        True
# 15               RandomUnderSampler()                       False
# 16                        passthrough                         NaN
# 17               RandomUnderSampler()                       False
# 18               RandomUnderSampler()                        True
# 19               RandomUnderSampler()                       False
# 20               RandomUnderSampler()                        True
# 21                        passthrough                         NaN
# 22                        passthrough                         NaN
# 23                        passthrough                         NaN
# 24                        passthrough                         NaN
# 25                        passthrough                         NaN
# 26               RandomUnderSampler()                        True
# 27                        passthrough                         NaN
# 28               RandomUnderSampler()                       False
# 29                        passthrough                         NaN
# 30               RandomUnderSampler()                       False
# 31               RandomUnderSampler()                        True
# 32                        passthrough                         NaN
#
#                                                        param_model  \
# rank_test_score
# 1                EasyEnsembleClassifier(n_estimators=100, repla...
# 2                EasyEnsembleClassifier(n_estimators=100, repla...
# 3                EasyEnsembleClassifier(n_estimators=100, repla...
# 4                EasyEnsembleClassifier(n_estimators=100, repla...
# 5                                             AdaBoostClassifier()
# 6                                             AdaBoostClassifier()
# 7                                 BalancedRandomForestClassifier()
# 8                                 BalancedRandomForestClassifier()
# 9                                 BalancedRandomForestClassifier()
# 10                                     BalancedBaggingClassifier()
# 11                                BalancedRandomForestClassifier()
# 12                                     BalancedBaggingClassifier()
# 13                                BalancedRandomForestClassifier()
# 14                                            AdaBoostClassifier()
# 15                                            AdaBoostClassifier()
# 16                                BalancedRandomForestClassifier()
# 17                                        RandomForestClassifier()
# 18                                        RandomForestClassifier()
# 19                                             BaggingClassifier()
# 20                                             BaggingClassifier()
# 21                                     BalancedBaggingClassifier()
# 22                                     BalancedBaggingClassifier()
# 23                                BalancedRandomForestClassifier()
# 24                                BalancedRandomForestClassifier()
# 25                                BalancedRandomForestClassifier()
# 26                                             BaggingClassifier()
# 27                                BalancedRandomForestClassifier()
# 28                                        RandomForestClassifier()
# 29                                BalancedRandomForestClassifier()
# 30                                             BaggingClassifier()
# 31                                        RandomForestClassifier()
# 32                                BalancedRandomForestClassifier()
#
#                 param_model__n_estimators param_model__replacement  \
# rank_test_score
# 1                                     100                     True
# 2                                     100                    False
# 3                                      10                    False
# 4                                      10                     True
# 5                                     100                      NaN
# 6                                     100                      NaN
# 7                                     100                    False
# 8                                     100                    False
# 9                                     100                     True
# 10                                    100                     True
# 11                                    100                     True
# 12                                    100                    False
# 13                                    100                     True
# 14                                     10                      NaN
# 15                                     10                      NaN
# 16                                    100                    False
# 17                                    100                      NaN
# 18                                    100                      NaN
# 19                                    100                      NaN
# 20                                    100                      NaN
# 21                                     10                     True
# 22                                     10                    False
# 23                                     10                     True
# 24                                     10                    False
# 25                                     10                     True
# 26                                     10                      NaN
# 27                                     10                    False
# 28                                     10                      NaN
# 29                                     10                     True
# 30                                     10                      NaN
# 31                                     10                      NaN
# 32                                     10                    False
#
#                 param_model__class_weight  \
# rank_test_score
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                    None
# 8                      balanced_subsample
# 9                                    None
# 10                                    NaN
# 11                     balanced_subsample
# 12                                    NaN
# 13                               balanced
# 14                                    NaN
# 15                                    NaN
# 16                               balanced
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                   None
# 24                     balanced_subsample
# 25                     balanced_subsample
# 26                                    NaN
# 27                                   None
# 28                                    NaN
# 29                               balanced
# 30                                    NaN
# 31                                    NaN
# 32                               balanced
#
#                                                             params  \
# rank_test_score
# 1                {'balancer': 'passthrough', 'model': EasyEnsem...
# 2                {'balancer': 'passthrough', 'model': EasyEnsem...
# 3                {'balancer': 'passthrough', 'model': EasyEnsem...
# 4                {'balancer': 'passthrough', 'model': EasyEnsem...
# 5                {'balancer': RandomUnderSampler(), 'balancer__...
# 6                {'balancer': RandomUnderSampler(), 'balancer__...
# 7                {'balancer': 'passthrough', 'model': BalancedR...
# 8                {'balancer': 'passthrough', 'model': BalancedR...
# 9                {'balancer': 'passthrough', 'model': BalancedR...
# 10               {'balancer': 'passthrough', 'model': BalancedB...
# 11               {'balancer': 'passthrough', 'model': BalancedR...
# 12               {'balancer': 'passthrough', 'model': BalancedB...
# 13               {'balancer': 'passthrough', 'model': BalancedR...
# 14               {'balancer': RandomUnderSampler(), 'balancer__...
# 15               {'balancer': RandomUnderSampler(), 'balancer__...
# 16               {'balancer': 'passthrough', 'model': BalancedR...
# 17               {'balancer': RandomUnderSampler(), 'balancer__...
# 18               {'balancer': RandomUnderSampler(), 'balancer__...
# 19               {'balancer': RandomUnderSampler(), 'balancer__...
# 20               {'balancer': RandomUnderSampler(), 'balancer__...
# 21               {'balancer': 'passthrough', 'model': BalancedB...
# 22               {'balancer': 'passthrough', 'model': BalancedB...
# 23               {'balancer': 'passthrough', 'model': BalancedR...
# 24               {'balancer': 'passthrough', 'model': BalancedR...
# 25               {'balancer': 'passthrough', 'model': BalancedR...
# 26               {'balancer': RandomUnderSampler(), 'balancer__...
# 27               {'balancer': 'passthrough', 'model': BalancedR...
# 28               {'balancer': RandomUnderSampler(), 'balancer__...
# 29               {'balancer': 'passthrough', 'model': BalancedR...
# 30               {'balancer': RandomUnderSampler(), 'balancer__...
# 31               {'balancer': RandomUnderSampler(), 'balancer__...
# 32               {'balancer': 'passthrough', 'model': BalancedR...
#
#                  mean_test_score  std_test_score
# rank_test_score
# 1                       0.692946        0.003480
# 2                       0.692751        0.003282
# 3                       0.692697        0.003615
# 4                       0.692642        0.003023
# 5                       0.686800        0.003617
# 6                       0.684443        0.003714
# 7                       0.675617        0.004227
# 8                       0.675379        0.004683
# 9                       0.674735        0.004383
# 10                      0.674332        0.006193
# 11                      0.674044        0.004436
# 12                      0.673731        0.003818
# 13                      0.672388        0.005362
# 14                      0.672098        0.004364
# 15                      0.671548        0.004083
# 16                      0.671535        0.003820
# 17                      0.670222        0.004368
# 18                      0.666997        0.003397
# 19                      0.663888        0.004324
# 20                      0.661777        0.004964
# 21                      0.635394        0.001875
# 22                      0.633446        0.003398
# 23                      0.631263        0.004199
# 24                      0.631039        0.004684
# 25                      0.630674        0.006311
# 26                      0.629412        0.004780
# 27                      0.628774        0.004121
# 28                      0.627483        0.003822
# 29                      0.627308        0.002494
# 30                      0.626955        0.004085
# 31                      0.626697        0.004113
# 32                      0.626043        0.005656

# %%
resultsDF = pd.DataFrame(GS.cv_results_)\
    .filter(regex=r"^(?!.*(split|time)).*$")\
    .set_index("rank_test_score").sort_index()

resultsDF
# Out:
#                        param_balancer param_balancer__replacement  \
# rank_test_score
# 1                         passthrough                         NaN
# 2                         passthrough                         NaN
# 3                         passthrough                         NaN
# 4                         passthrough                         NaN
# 5                RandomUnderSampler()                       False
# 6                RandomUnderSampler()                        True
# 7                         passthrough                         NaN
# 8                         passthrough                         NaN
# 9                         passthrough                         NaN
# 10                        passthrough                         NaN
# 11                        passthrough                         NaN
# 12                        passthrough                         NaN
# 13                        passthrough                         NaN
# 14               RandomUnderSampler()                        True
# 15               RandomUnderSampler()                       False
# 16                        passthrough                         NaN
# 17               RandomUnderSampler()                       False
# 18               RandomUnderSampler()                        True
# 19               RandomUnderSampler()                       False
# 20               RandomUnderSampler()                        True
# 21                        passthrough                         NaN
# 22                        passthrough                         NaN
# 23                        passthrough                         NaN
# 24                        passthrough                         NaN
# 25                        passthrough                         NaN
# 26               RandomUnderSampler()                        True
# 27                        passthrough                         NaN
# 28               RandomUnderSampler()                       False
# 29                        passthrough                         NaN
# 30               RandomUnderSampler()                       False
# 31               RandomUnderSampler()                        True
# 32                        passthrough                         NaN
#
#                                                        param_model  \
# rank_test_score
# 1                EasyEnsembleClassifier(n_estimators=100, repla...
# 2                EasyEnsembleClassifier(n_estimators=100, repla...
# 3                EasyEnsembleClassifier(n_estimators=100, repla...
# 4                EasyEnsembleClassifier(n_estimators=100, repla...
# 5                                             AdaBoostClassifier()
# 6                                             AdaBoostClassifier()
# 7                                 BalancedRandomForestClassifier()
# 8                                 BalancedRandomForestClassifier()
# 9                                 BalancedRandomForestClassifier()
# 10                                     BalancedBaggingClassifier()
# 11                                BalancedRandomForestClassifier()
# 12                                     BalancedBaggingClassifier()
# 13                                BalancedRandomForestClassifier()
# 14                                            AdaBoostClassifier()
# 15                                            AdaBoostClassifier()
# 16                                BalancedRandomForestClassifier()
# 17                                        RandomForestClassifier()
# 18                                        RandomForestClassifier()
# 19                                             BaggingClassifier()
# 20                                             BaggingClassifier()
# 21                                     BalancedBaggingClassifier()
# 22                                     BalancedBaggingClassifier()
# 23                                BalancedRandomForestClassifier()
# 24                                BalancedRandomForestClassifier()
# 25                                BalancedRandomForestClassifier()
# 26                                             BaggingClassifier()
# 27                                BalancedRandomForestClassifier()
# 28                                        RandomForestClassifier()
# 29                                BalancedRandomForestClassifier()
# 30                                             BaggingClassifier()
# 31                                        RandomForestClassifier()
# 32                                BalancedRandomForestClassifier()
#
#                 param_model__n_estimators param_model__replacement  \
# rank_test_score
# 1                                     100                     True
# 2                                     100                    False
# 3                                      10                    False
# 4                                      10                     True
# 5                                     100                      NaN
# 6                                     100                      NaN
# 7                                     100                    False
# 8                                     100                    False
# 9                                     100                     True
# 10                                    100                     True
# 11                                    100                     True
# 12                                    100                    False
# 13                                    100                     True
# 14                                     10                      NaN
# 15                                     10                      NaN
# 16                                    100                    False
# 17                                    100                      NaN
# 18                                    100                      NaN
# 19                                    100                      NaN
# 20                                    100                      NaN
# 21                                     10                     True
# 22                                     10                    False
# 23                                     10                     True
# 24                                     10                    False
# 25                                     10                     True
# 26                                     10                      NaN
# 27                                     10                    False
# 28                                     10                      NaN
# 29                                     10                     True
# 30                                     10                      NaN
# 31                                     10                      NaN
# 32                                     10                    False
#
#                 param_model__class_weight  \
# rank_test_score
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                    None
# 8                      balanced_subsample
# 9                                    None
# 10                                    NaN
# 11                     balanced_subsample
# 12                                    NaN
# 13                               balanced
# 14                                    NaN
# 15                                    NaN
# 16                               balanced
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                   None
# 24                     balanced_subsample
# 25                     balanced_subsample
# 26                                    NaN
# 27                                   None
# 28                                    NaN
# 29                               balanced
# 30                                    NaN
# 31                                    NaN
# 32                               balanced
#
#                                                             params  \
# rank_test_score
# 1                {'balancer': 'passthrough', 'model': EasyEnsem...
# 2                {'balancer': 'passthrough', 'model': EasyEnsem...
# 3                {'balancer': 'passthrough', 'model': EasyEnsem...
# 4                {'balancer': 'passthrough', 'model': EasyEnsem...
# 5                {'balancer': RandomUnderSampler(), 'balancer__...
# 6                {'balancer': RandomUnderSampler(), 'balancer__...
# 7                {'balancer': 'passthrough', 'model': BalancedR...
# 8                {'balancer': 'passthrough', 'model': BalancedR...
# 9                {'balancer': 'passthrough', 'model': BalancedR...
# 10               {'balancer': 'passthrough', 'model': BalancedB...
# 11               {'balancer': 'passthrough', 'model': BalancedR...
# 12               {'balancer': 'passthrough', 'model': BalancedB...
# 13               {'balancer': 'passthrough', 'model': BalancedR...
# 14               {'balancer': RandomUnderSampler(), 'balancer__...
# 15               {'balancer': RandomUnderSampler(), 'balancer__...
# 16               {'balancer': 'passthrough', 'model': BalancedR...
# 17               {'balancer': RandomUnderSampler(), 'balancer__...
# 18               {'balancer': RandomUnderSampler(), 'balancer__...
# 19               {'balancer': RandomUnderSampler(), 'balancer__...
# 20               {'balancer': RandomUnderSampler(), 'balancer__...
# 21               {'balancer': 'passthrough', 'model': BalancedB...
# 22               {'balancer': 'passthrough', 'model': BalancedB...
# 23               {'balancer': 'passthrough', 'model': BalancedR...
# 24               {'balancer': 'passthrough', 'model': BalancedR...
# 25               {'balancer': 'passthrough', 'model': BalancedR...
# 26               {'balancer': RandomUnderSampler(), 'balancer__...
# 27               {'balancer': 'passthrough', 'model': BalancedR...
# 28               {'balancer': RandomUnderSampler(), 'balancer__...
# 29               {'balancer': 'passthrough', 'model': BalancedR...
# 30               {'balancer': RandomUnderSampler(), 'balancer__...
# 31               {'balancer': RandomUnderSampler(), 'balancer__...
# 32               {'balancer': 'passthrough', 'model': BalancedR...
#
#                  mean_test_score  std_test_score
# rank_test_score
# 1                       0.692946        0.003480
# 2                       0.692751        0.003282
# 3                       0.692697        0.003615
# 4                       0.692642        0.003023
# 5                       0.686800        0.003617
# 6                       0.684443        0.003714
# 7                       0.675617        0.004227
# 8                       0.675379        0.004683
# 9                       0.674735        0.004383
# 10                      0.674332        0.006193
# 11                      0.674044        0.004436
# 12                      0.673731        0.003818
# 13                      0.672388        0.005362
# 14                      0.672098        0.004364
# 15                      0.671548        0.004083
# 16                      0.671535        0.003820
# 17                      0.670222        0.004368
# 18                      0.666997        0.003397
# 19                      0.663888        0.004324
# 20                      0.661777        0.004964
# 21                      0.635394        0.001875
# 22                      0.633446        0.003398
# 23                      0.631263        0.004199
# 24                      0.631039        0.004684
# 25                      0.630674        0.006311
# 26                      0.629412        0.004780
# 27                      0.628774        0.004121
# 28                      0.627483        0.003822
# 29                      0.627308        0.002494
# 30                      0.626955        0.004085
# 31                      0.626697        0.004113
# 32                      0.626043        0.005656

# %%
resultsDF.to_csv("ResultsGridsearchArthritisSeverityClasses.csv", index=False)
